# %% [markdown]
# # ipywardley
#
# Run this on [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/anjackson/ipywardley/main?filepath=test%2Fwardley-maps.ipynb) or [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/anjackson/ipywardley/blob/main/test/wardley-maps.ipynb)
#
# ## Installation & Setup
#
# To bring Wardley Map magic to your notebook, first check ipywardley is installed: and then load the `ipywardley` extension:

# %%
# !pip install -U ipywardley
# Out:
# Requirement already satisfied: ipywardley in /Users/andy/Documents/workspace/ipywardley/venv/lib/python3.7/site-packages (0.0.3)
# Requirement already satisfied: matplotlib in /Users/andy/Documents/workspace/ipywardley/venv/lib/python3.7/site-packages (from ipywardley) (3.4.2)
# Requirement already satisfied: ipython in /Users/andy/Documents/workspace/ipywardley/venv/lib/python3.7/site-packages (from ipywardley) (7.25.0)
# Requirement already satisfied: appnope in /Users/andy/Documents/workspace/ipywardley/venv/lib/python3.7/site-packages (from ipython->ipywardley) (0.1.2)
# Requirement already satisfied: pygments in /Users/andy/Documents/workspace/ipywardley/venv/lib/python3.7/site-packages (from ipython->ipywardley) (2.9.0)
# Requirement already satisfied: traitlets>=4.2 in /Users/andy/Documents/workspace/ipywardley/venv/lib/python3.7/site-packages (from ipython->ipywardley) (5.0.5)
# Requirement already satisfied: pickleshare in /Users/andy/Documents/workspace/ipywardley/venv/lib/python3.7/site-packages (from ipython->ipywardley) (0.7.5)
# Requirement already satisfied: pexpect>4.3 in /Users/andy/Documents/workspace/ipywardley/venv/lib/python3.7/site-packages (from ipython->ipywardley) (4.8.0)
# Requirement already satisfied: backcall in /Users/andy/Documents/workspace/ipywardley/venv/lib/python3.7/site-packages (from ipython->ipywardley) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /Users/andy/Documents/workspace/ipywardley/venv/lib/python3.7/site-packages (from ipython->ipywardley) (0.1.2)
# Requirement already satisfied: decorator in /Users/andy/Documents/workspace/ipywardley/venv/lib/python3.7/site-packages (from ipython->ipywardley) (5.0.9)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/andy/Documents/workspace/ipywardley/venv/lib/python3.7/site-packages (from ipython->ipywardley) (3.0.19)
# Requirement already satisfied: setuptools>=18.5 in /Users/andy/Documents/workspace/ipywardley/venv/lib/python3.7/site-packages (from ipython->ipywardley) (57.0.0)
# Requirement already satisfied: jedi>=0.16 in /Users/andy/Documents/workspace/ipywardley/venv/lib/python3.7/site-packages (from ipython->ipywardley) (0.18.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/andy/Documents/workspace/ipywardley/venv/lib/python3.7/site-packages (from jedi>=0.16->ipython->ipywardley) (0.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/andy/Documents/workspace/ipywardley/venv/lib/python3.7/site-packages (from pexpect>4.3->ipython->ipywardley) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/andy/Documents/workspace/ipywardley/venv/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->ipywardley) (0.2.5)
# Requirement already satisfied: ipython-genutils in /Users/andy/Documents/workspace/ipywardley/venv/lib/python3.7/site-packages (from traitlets>=4.2->ipython->ipywardley) (0.2.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/andy/Documents/workspace/ipywardley/venv/lib/python3.7/site-packages (from matplotlib->ipywardley) (8.3.1)
# Requirement already satisfied: numpy>=1.16 in /Users/andy/Documents/workspace/ipywardley/venv/lib/python3.7/site-packages (from matplotlib->ipywardley) (1.21.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/andy/Documents/workspace/ipywardley/venv/lib/python3.7/site-packages (from matplotlib->ipywardley) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/andy/Documents/workspace/ipywardley/venv/lib/python3.7/site-packages (from matplotlib->ipywardley) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/andy/Documents/workspace/ipywardley/venv/lib/python3.7/site-packages (from matplotlib->ipywardley) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/andy/Documents/workspace/ipywardley/venv/lib/python3.7/site-packages (from matplotlib->ipywardley) (2.4.7)
# Requirement already satisfied: six in /Users/andy/Documents/workspace/ipywardley/venv/lib/python3.7/site-packages (from cycler>=0.10->matplotlib->ipywardley) (1.16.0)
# WARNING: You are using pip version 21.1.2; however, version 21.1.3 is available.
# You should consider upgrading via the '/Users/andy/Documents/workspace/ipywardley/venv/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# ...and then load the `ipywardley` Jupyter notebook extension:

# %%
# %load_ext ipywardley

# %% [markdown]
# Then set up matplot lib so it makes nice images:

# %%
# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline

# %% [markdown]
# ## Usage
#
# You can now use the `%%wardley` IPython magic to define a map using the simple language defined by [Online Wardley Maps (OWM)](https://onlinewardleymaps.com/). See the syntax reference underneath the diagram on that page for more details.
#
# Here's a simple example taken from OWM:

# %%
# %%wardley
# title Tea Shop
# anchor Business [0.95, 0.63]
# anchor Public [0.95, 0.78]
# component Cup of Tea [0.79, 0.61] label [19, -4]
# component Cup [0.73, 0.78]
# component Tea [0.63, 0.81]
# component Hot Water [0.52, 0.80]
# component Water [0.38, 0.82]
# component Kettle [0.43, 0.35] label [-57, 4]
# component Power [0.1, 0.7] label [-27, 20]
# Business->Cup of Tea
# Public->Cup of Tea
# Cup of Tea->Cup
# Cup of Tea->Tea
# Cup of Tea->Hot Water
# Hot Water->Water
# Hot Water->Kettle
# Kettle->Power
#
# note +a generic note appeared [0.23, 0.33]
#
# # Any matplotlib style should work, as well as 'wardley' and 'xkcd'/'handwritten'
# style wardley

# %% [markdown]
# As you can see the `wardley` style attempts to use the formatting and design that Simon Wardley uses.
#
# The following example is in the `plain` style, and illustrates that this implementation only covers a subset of the full OWM syntax.

# %%
# %%wardley test
# title Tea Shop
# anchor Business [0.95, 0.63]
# anchor Public [0.95, 0.78]
# component Cup of Tea [0.79, 0.61] label [19, -4]
# component Cup [0.73, 0.78]
# component Tea [0.63, 0.81]
# component Hot Water [0.52, 0.80]
# component Water [0.38, 0.82]
# component Kettle [0.43, 0.35] label [-57, 4]
# evolve Kettle 0.62 label [16, 7]
# component Power [0.1, 0.7] label [-27, 20]
# evolve Power 0.89 label [-12, 21]
# Business->Cup of Tea
# Public->Cup of Tea
# Cup of Tea->Cup
# Cup of Tea->Tea
# Cup of Tea->Hot Water
# Hot Water->Water
# Hot Water->Kettle
# Kettle->Power
#
# annotation 1 [[0.43,0.49],[0.08,0.79]] Standardising power allows Kettles to evolve faster
# annotation 2 [0.48, 0.85] Hot water is obvious and well known
# annotations [0.60, 0.02]
#
# note +a generic note appeared [0.23, 0.33]
#
# style plain
# Out:
# <strong>WARNING:</strong> Could not parse line: annotation 1 [[0.43,0.49],[0.08,0.79]] Standardising power allows Kettles to evolve faster
# <strong>WARNING:</strong> Could not parse line: annotation 2 [0.48, 0.85] Hot water is obvious and well known
# <strong>WARNING:</strong> Could not parse line: annotations [0.60, 0.02]
# <strong>WARNING:</strong> Displaying evolutions is not implemented yet!

# %% [markdown]
# You can also use the styles included with `matplotlib`, including the `xkcd` style for a more handwritten feel:

# %%
# %%wardley test
# title Tea Shop
# anchor Business [0.95, 0.63]
# anchor Public [0.95, 0.78]
# component Cup of Tea [0.79, 0.61] label [19, -4]
# component Cup [0.73, 0.78]
# component Tea [0.63, 0.81]
# component Hot Water [0.52, 0.80]
# component Water [0.38, 0.82]
# component Kettle [0.43, 0.35] label [-57, 4]
# component Power [0.1, 0.7] label [-27, 20]
# Business->Cup of Tea
# Public->Cup of Tea
# Cup of Tea->Cup
# Cup of Tea->Tea
# Cup of Tea->Hot Water
# Hot Water->Water
# Hot Water->Kettle
# Kettle->Power
#
# note +a generic note appeared [0.23, 0.33]
#
# style xkcd
